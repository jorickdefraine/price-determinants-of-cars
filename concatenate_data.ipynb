# %%
import pandas as pd

# %%
df = pd.read_csv("Cars_DB.csv", index_col=None, header=0)

# %%
df.head()
# Out:
#    Unnamed: 0                          nom  \
# 0           0   CITROEN C3 (3E GENERATION)
# 1           1          CITROEN C3 AIRCROSS
# 2           2                 PEUGEOT 2008
# 3           3  PEUGEOT 208 (2E GENERATION)
# 4           4          MINI MINI 3 CLUBMAN
#
#                                                model    price  \
# 0           CITROEN C3 III 1.2 PURETECH 82 S&S SHINE  16 300€
# 1                     1.5 BLUEHDI 120 S&S EAT6 SHINE  26 290€
# 2                 (2) PURETECH 110 S&S CROSSWAY EAT6  21 700€
# 3         PEUGEOT 208 II 1.2 PURETECH 100 S&S ALLURE  22 590€
# 4  MINI MINI CLUBMAN III CLUBMAN COOPER FINITION ...  31 090€
#
#   Mise_en_circluation Kilométrage_compteur  Energie Boite_de_vitesse  \
# 0          17/02/2019            12 805 Km  Essence        mécanique
# 1          13/01/2022             4 683 Km   Diesel      automatique
# 2          26/04/2020            19 209 Km  Essence      automatique
# ...

# %%
all_files = ["Cars_DB.csv", "392_Cars_DB.csv", "1765_Cars_DB.csv", "2197_Cars_DB.csv",
            "2415_Cars_DB.csv", "2900_Cars_DB.csv", "3836_Cars_DB.csv"]

# %%
li=[]
for filename in all_files:

    df = pd.read_csv(filename, index_col=None, header=0)

    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame.tail()
# Out:
#        Unnamed: 0                 nom  \
# 60475          75        OPEL CORSA 5
# 60476          76    HYUNDAI TERRACAN
# 60477          77      DACIA DUSTER 2
# 60478          78  CITROEN BERLINGO 3
# 60479          79           KIA XCEED
#
#                                                    model    price  \
# 60475              OPEL CORSA V 1.4 90 DESIGN 120 ANS 5P  14 110€
# 60476                            2.9 CRDI PACK CLIM 11CV   7 120€
# 60477      DACIA DUSTER II 1.5 DCI 115 BLUE PRESTIGE 4X2  20 790€
# 60478  CITROEN BERLINGO III TAILLE M 650KG BLUEHDI 10...  19 240€
# 60479                       1.6 CRDI 115 ISG ACTIVE DCT7  29 860€
#
#       Mise_en_circluation Kilométrage_compteur  Energie Boite_de_vitesse  \
# 60475          06/08/2020            26 624 Km  Essence        mécanique
# 60476          31/01/2006           214 318 Km   Diesel        mécanique
# 60477          01/03/2021             6 408 Km   Diesel        mécanique
# ...

# %%
frame.to_csv('final_Cars_DB.csv', index=False)
